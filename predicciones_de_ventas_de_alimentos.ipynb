# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoFigueroa19/dojo_proyecto1/blob/main/predicciones_de_ventas_de_alimentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

filename = "/content/drive/MyDrive/Dojo/Unidad 1/Proyecto1/sales_predictions_2023.csv"
# importamos Pandas
df = pd.read_csv(filename) # Carga de Archivo

df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
len (df.columns )
# Out:
# 12

# %% [markdown]
# Proyecto parte 2
# R1 .- Tenemos 12 Columnas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
Aca el detalle de cada Variable y tenemos 8523 Filas

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No hay Duplicados

# %%
df["Outlet_Type"].value_counts()
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# Faltan DAtos en Outlet_size 2410 e Item_weight son 1463

# %%
df = df.drop(columns=['Item_Weight', 'Outlet_Size'])
df
# Out:
#      Item_Identifier Item_Fat_Content  Item_Visibility              Item_Type  \
# 0              FDA15          Low Fat         0.016047                  Dairy
# 1              DRC01          Regular         0.019278            Soft Drinks
# 2              FDN15          Low Fat         0.016760                   Meat
# 3              FDX07          Regular         0.000000  Fruits and Vegetables
# 4              NCD19          Low Fat         0.000000              Household
# ...              ...              ...              ...                    ...
# 8518           FDF22          Low Fat         0.056783            Snack Foods
# 8519           FDS36          Regular         0.046982           Baking Goods
# 8520           NCJ29          Low Fat         0.035186     Health and Hygiene
# 8521           FDN46          Regular         0.145221            Snack Foods
# 8522           DRG01          Low Fat         0.044878            Soft Drinks
#
# ...

# %% [markdown]
# Se eliminan las columas con los datos faltantes en lugar del tamaño de la tienda usaremos el tipo de tienda y el peso del item sera descartado del analisis

# %%
df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# No tenemos Datos Nulos

# %%
import numpy as np
columnas = np.array (df.columns.values)

len (columnas)

for i in range  (0,len(columnas) - 1,1) :

      print (df[columnas[i ]].value_counts())
# Out:
# Item_Identifier
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: count, Length: 1559, dtype: int64
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64
# Item_Visibility
# 0.000000    526
# 0.076975      3
# 0.162462      2
# 0.076841      2
# 0.073562      2
#            ...
# 0.013957      1
# 0.110460      1
# 0.124646      1
# 0.054142      1
# 0.044878      1
# Name: count, Length: 7880, dtype: int64
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# ...

# %% [markdown]
# Item_Fat_Content tiene categorias extrañas para Low Fat

# %%
df["Item_Fat_Content"].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('LF', 'Low Fat') # indicamos que lf es Low Fat
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('reg', 'Regular') # indicamos que reg es Regular
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('low fat', 'Low Fat') # indicamos que reg es Regular


df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %% [markdown]
# Corregimos el Item de contenido de Grasa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Fat_Content           8523 non-null   object
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   object
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Identifier          8523 non-null   object
#  6   Outlet_Establishment_Year  8523 non-null   int64
#  7   Outlet_Location_Type       8523 non-null   object
#  8   Outlet_Type                8523 non-null   object
#  9   Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 666.0+ KB

# %%
df["Item_Visibility"].max(),df["Item_Visibility"].min(),df["Item_Visibility"].sum()
# Out:
# (0.328390948, 0.0, 563.6432812830001)

# %%
df["Item_MRP"].max(),df["Item_MRP"].min(),df["Item_MRP"].sum()
# Out:
# (266.8884, 31.29, 1201681.4808)

# %%
df["Outlet_Establishment_Year"].max(),df["Outlet_Establishment_Year"].min(),df["Outlet_Establishment_Year"].sum()
# Out:
# (2009, 1985, 17027521)

# %%
df["Item_Outlet_Sales"].max(),df["Item_Outlet_Sales"].min(),df["Item_Outlet_Sales"].sum()
# Out:
# (13086.9648, 33.29, 18591125.4104)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Fat_Content           8523 non-null   object
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   object
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Identifier          8523 non-null   object
#  6   Outlet_Establishment_Year  8523 non-null   int64
#  7   Outlet_Location_Type       8523 non-null   object
#  8   Outlet_Type                8523 non-null   object
#  9   Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 666.0+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df['Item_Outlet_Sales'].hist()
# Out:
# <Axes: >

# %%
venta= df['Item_Outlet_Sales']
item  = df['Item_MRP']

#perro = df.loc[df['Mean Number of Dogs']=='P','Number of Households (in 1000)'].values
#gato = df.loc[df['Mean Number of Cats']=='G','Number of Households (in 1000)'].values
plt.boxplot([venta, item], labels=['V', 'I'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d0cecf0b010>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d0cecf0b550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d0cecf0ad70>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7d0cecf0ba90>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7d0cecf0bd30>,
# ...
#  'means': []}

# %%
df.head()
# Out:
#   Item_Identifier Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           FDA15          Low Fat         0.016047                  Dairy
# 1           DRC01          Regular         0.019278            Soft Drinks
# 2           FDN15          Low Fat         0.016760                   Meat
# 3           FDX07          Regular         0.000000  Fruits and Vegetables
# 4           NCD19          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Location_Type  \
# 0  249.8092            OUT049                       1999               Tier 1
# 1   48.2692            OUT018                       2009               Tier 3
# 2  141.6180            OUT049                       1999               Tier 1
# 3  182.0950            OUT010                       1998               Tier 3
# 4   53.8614            OUT013                       1987               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# ...

# %%
Dfval = df[ ['Item_Visibility', 'Item_MRP' ,'Item_Outlet_Sales' ]]

corr = Dfval.corr()

# %%
import seaborn as sns
sns.heatmap(corr, cmap = 'Greens' , annot = True  )
# Out:
# <Axes: >

# %%
df.head()
# Out:
#   Item_Identifier Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           FDA15          Low Fat         0.016047                  Dairy
# 1           DRC01          Regular         0.019278            Soft Drinks
# 2           FDN15          Low Fat         0.016760                   Meat
# 3           FDX07          Regular         0.000000  Fruits and Vegetables
# 4           NCD19          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Location_Type  \
# 0  249.8092            OUT049                       1999               Tier 1
# 1   48.2692            OUT018                       2009               Tier 3
# 2  141.6180            OUT049                       1999               Tier 1
# 3  182.0950            OUT010                       1998               Tier 3
# 4   53.8614            OUT013                       1987               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# ...

# %%
VentaXoutlet  = df.groupby('Outlet_Location_Type')['Item_Outlet_Sales'].sum()
VentaXfat     = df.groupby('Item_Fat_Content')['Item_Outlet_Sales'].sum()

VentaXoutlet
# Out:
# Outlet_Location_Type
# Tier 1    4.482059e+06
# Tier 2    6.472314e+06
# Tier 3    7.636753e+06
# Name: Item_Outlet_Sales, dtype: float64

# %%
ventas = df.groupby('Outlet_Location_Type')['Item_Outlet_Sales'].sum()  # ventas y location

plt.bar(ventas.index, ventas.values);

# %%
VentaXfat     = df.groupby('Item_Fat_Content')['Item_Outlet_Sales'].sum()
plt.bar(VentaXfat.index, VentaXfat.values);

# %%
VentaXitem  = df.groupby('Item_Type')['Item_Outlet_Sales'].sum()
plt.bar(VentaXitem.index, VentaXitem.values);
